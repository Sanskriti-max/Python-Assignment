# %%
nums = []
for i in range(10):
    n = int(input("Enter number: "))
    nums.append(n)
nums.sort()

print("Smallest =", nums[0])
print("Second Largest =", nums[-2])
print("Largest =", nums[-1])
# Out:
# Smallest = 3
# Second Largest = 67
# Largest = 98

# %%
x = input("Enter a string: ")
vowels = consonants = digits = special = 0

for ch in x:
    if ch.isalpha():
        if ch.lower() in "aeiou":
            vowels += 1
        else:
            consonants += 1
    elif ch.isdigit():
        digits += 1
    else:
        special += 1

print("Vowels =", vowels)
print("Consonants =", consonants)
print("Digits =", digits)
print("Special Characters =", special)
# Out:
# Vowels = 3
# Consonants = 6
# Digits = 0
# Special Characters = 0

# %%
num = int(input("Enter a number: "))

temp = num
digits = len(str(num))
sum1 = 0

while temp > 0:
    rem = temp % 10
    sum1 += rem ** digits
    temp //= 10

if sum1 == num:
    print("Armstrong Number")
else:
    print("Not an Armstrong Number")
# Out:
# Not an Armstrong Number

# %%
t = (1, 2, 3, 2, 4, 5, 1, 2, 3)

for item in set(t):
    if t.count(item) > 1:
        print(item, "appears", t.count(item), "times")
# Out:
# 1 appears 2 times
# 2 appears 3 times
# 3 appears 2 times

# %%
students = (
    ("princi", 85),
    ("Sanskriti", 92),
    ("Aman", 88)
)

topper = max(students, key=lambda x: x[1])

print("Topper:", topper[0])
print("Marks:", topper[1])
# Out:
# Topper: Sanskriti
# Marks: 92

# %%
sentence = input("Enter a sentence: ")

words = sentence.split()

freq = {}

for word in words:
    freq[word] = freq.get(word, 0) + 1

print(freq)
# Out:
# {'my': 1, 'name': 1, 'is': 1, 'sanskriti': 1, 'and': 1, 'I': 1, 'want': 1, 'to': 1, 'bacame': 1, 'an': 1, 'AIML': 1, 'engineer': 1}

# %%
students = {
    "Rahul": 80,
    "Priya": 95,
    "Aman": 70,
    "Riya": 90
}

avg = sum(students.values()) / len(students)

print("Average =", avg)

print("Students above average:")
for name, marks in students.items():
    if marks > avg:
        print(name, marks)
# Out:
# Average = 83.75
# Students above average:
# Priya 95
# Riya 90

# %%
products = {}

while True:
    print("\n1.Add Product")
    print("2.View Products")
    print("3.Delete Product")
    print("4.Exit")

    choice = int(input("Enter choice: "))

    if choice == 1:
        name = input("Product Name: ")
        price = float(input("Price: "))
        products[name] = price

    elif choice == 2:
        print(products)

    elif choice == 3:
        name = input("Enter product name: ")
        if name in products:
            del products[name]

    elif choice == 4:
        break

    else:
        print("Invalid Choice")
# Out:
# 1.Add Product
# 2.View Products
# 3.Delete Product
# 4.Exit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 9
#       5     print("2.View Products")
#       6     print("3.Delete Product")
#       7     print("4.Exit")
#       8
# ----> 9     choice = int(input("Enter choice: "))
#      10
#      11     if choice == 1:
#      12         name = input("Product Name: ")
#
# ValueError: invalid literal for int() with base 10: ''

# %%
a = int(input("Enter side 1: "))
b = int(input("Enter side 2: "))
c = int(input("Enter side 3: "))

if a == b == c:
    print("Equilateral Triangle")
elif a == b or b == c or a == c:
    print("Isosceles Triangle")
else:
    print("Scalene Triangle")
# Out:
# Scalene Triangle

# %%
students = {}

while True:
    print("\n1. Add Student")
    print("2. View Students")
    print("3. Search Student")
    print("4. Exit")

    choice = int(input("Enter choice: "))

    if choice == 1:
        roll = input("Enter Roll No: ")
        name = input("Enter Name: ")
        marks = int(input("Enter Marks: "))

        students[roll] = (name, marks)

    elif choice == 2:
        for roll, data in students.items():
            print("Roll:", roll,
                  "Name:", data[0],
                  "Marks:", data[1])

    elif choice == 3:
        roll = input("Enter Roll No: ")

        if roll in students:
            print(students[roll])
        else:
            print("Student Not Found")

    elif choice == 4:
        break

    else:
        print("Invalid Choice")
# Out:
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Exit
#
# 1. Add Student
# 2. View Students
# 3. Search Student
# 4. Exit
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 9
#       5     print("2. View Students")
#       6     print("3. Search Student")
#       7     print("4. Exit")
#       8
# ----> 9     choice = int(input("Enter choice: "))
#      10
#      11     if choice == 1:
#      12         roll = input("Enter Roll No: ")
#
# ValueError: invalid literal for int() with base 10: ''
